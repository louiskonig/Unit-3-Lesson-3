# %%
# Imports
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
data = pd.DataFrame()
data['x'] = np.random.normal(0, .5, 1000)
data['y'] = np.random.normal(0, .5, 1000)

# Create your circle of indicators
data['d'] = data.x**2 + (data.y)**2 < .2

plt.figure(figsize=(5,5))
plt.scatter(data['x'], data['y'], c=data['d'], s= 20)

# %%
data.head()
# Out:
#           x         y      d
# 0  0.003025 -0.984116  False
# 1  0.038421 -1.408524  False
# 2  0.140347  0.438349  False
# 3  0.114236 -0.324217   True
# 4  0.326241 -0.243070   True

# %%
# We're doing some 3D plotting now. 
# Tinker with it if you like but python is generally not great at this kind of thing...

from mpl_toolkits.mplot3d import Axes3D

# Make our new variable
data['x2_y2'] = data.x**2 + data.y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs=data.x, ys=data.y, zs=data.x2_y2, zdir='z', c=data.d)

# %%
from mpl_toolkits.mplot3d import Axes3D

# Make our new variable
data['x2_y2'] = data.x**2 + data.y**2


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

xx, yy = np.meshgrid(range(-5, 5, 1), range(-5, 5, 1))
ax.plot_surface(xx, yy, .2, color='k', alpha=.5)
ax.hold(True)
ax.scatter(xs=data.x, ys=data.y, zs=data.x2_y2, zdir='z', c=data.d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-796492395d03> in <module>()
#      10
#      11 xx, yy = np.meshgrid(range(-5, 5, 1), range(-5, 5, 1))
# ---> 12 ax.plot_surface(xx, yy, .2, color='k', alpha=.5)
#      13 ax.hold(True)
#      14 ax.scatter(xs=data.x, ys=data.y, zs=data.x2_y2, zdir='z', c=data.d)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1619         had_data = self.has_data()
#    1620
# -> 1621         if Z.ndim != 2:
#    1622             raise ValueError("Argument Z must be 2-dimensional.")
#    1623         # TODO: Support masked arrays
#
# AttributeError: 'float' object has no attribute 'ndim'

# %%
xx.
